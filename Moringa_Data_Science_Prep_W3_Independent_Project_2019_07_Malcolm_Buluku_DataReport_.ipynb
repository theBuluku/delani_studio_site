# %% [markdown]
# <a href="https://colab.research.google.com/github/theBuluku/delani_studio_site/blob/master/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Malcolm_Buluku_DataReport_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading pandas and numpy environments
import pandas as pd
import numpy as np

# %%
#loading the first dataset
df1 = pd.read_csv('MoringaSchool_CB_CDR_20120508.csv')
df1.tail(10)
# Out:
#         PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 3057369   Voice     82  2012-05-08 08:57:08.0  ...     19e2e  d6c0cf1480  66e2080825
# 3057370   Voice      2  2012-05-08 08:57:08.0  ...     19e2e  4de2ef1ec9  59a53648cd
# 3057371   Voice      0  2012-05-08 08:57:08.0  ...     19e2e  f8f987f764  651c6d67d4
# 3057372   Voice      0  2012-05-08 08:57:08.0  ...     19e2e  216c513ea6  d982ba5017
# 3057373   Voice      0  2012-05-08 08:57:08.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 3057374   Voice     53  2012-05-08 08:57:08.0  ...     19e2e  f80981dc41  442f476021
# 3057375   Voice     14  2012-05-08 08:57:08.0  ...     19e2e  9740ee04d6  9ef9616350
# 3057376   Voice    118  2012-05-08 08:57:08.0  ...     19e2e  bd5a483b69  4849c3cf05
# 3057377   Voice     11  2012-05-08 08:57:08.0  ...     19e2e  29caa59e7a  d97af85bcd
# 3057378   Voice    109  2012-05-08 08:57:08.0  ...         1         NaN         NaN
#
# [10 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3057379 entries, 0 to 3057378
# Data columns (total 10 columns):
# PRODUCT         object
# VALUE           int64
# DATE_TIME       object
# CELL_ON_SITE    object
# DW_A_NUMBER     object
# DW_B_NUMBER     object
# COUNTRY_A       object
# COUNTRY_B       object
# CELL_ID         object
# SITE_ID         object
# dtypes: int64(1), object(9)
# memory usage: 233.3+ MB

# %%
df1_new= df1.rename(columns={
   'PRODUTC' : 'PRODUCTS', 'VALUE' : 'VALUES',
   'DATETIME' : 'DATE_TIME',
   'CELL_ON_SITE':'CELL_ON_SITE', 'DW_A_NUMBER_INT' : 'DW_A_NUMBER_INT',
   'DW_B_NUMBER_INT' : 'DW_B_NUMBER_INT',
   'COUNTRY_A' : 'COUNTRY_A',
   'COUNTRY_B' : 'COUNTRY_B',
   'CELL_ID' : 'CELL_ID',
   'SIET_ID' : 'SITE_ID'
})
print(df1_new)
df1.tail(10)
# Out:
#         PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0           sms       0  ...  +854AcBQT2  +854AcBQT2
# 1         Voice       0  ...  +854AcBQT2  +854AcBQT2
# 2           sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 3         Voice      37  ...  /xvRrCVKoQ  /xvRrCVKoQ
# 4           sms      25  ...  +bO+qkSonO  +bO+qkSonO
# 5           sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 6         Voice      41  ...  +laSrk7g6q  +laSrk7g6q
# 7         Voice      11  ...  +gySf02tKW  +gySf02tKW
# 8           sms       0  ...  /0FxP3az1x  /0FxP3az1x
# 9           sms       0  ...  0ecjmwPX21  0ecjmwPX21
# 10          sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 11          sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 12          sms       0  ...  +YzQI97cPp  +YzQI97cPp
# 13          sms       0  ...  +38u2u/rfx  +38u2u/rfx
# 14          sms       0  ...  0BRdojv2my  0BRdojv2my
# 15          sms       0  ...  +e+xcimwre  +e+xcimwre
# 16          sms       0  ...  +cNeJzsTp3  +cNeJzsTp3
# ...

# %%
df2 = pd.read_csv('MoringaSchool_CB_CDR_20120507.csv')
df2.tail(10)
# Out:
#         PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 1283575     sms      0  2012-05-07 07:47:41.0  ...     19e2e  9f1eeee836  1ddea341cd
# 1283576     sms      0  2012-05-07 07:47:41.0  ...     19e2e  7e069ea2c0  c1ec9c885f
# 1283577     sms      0  2012-05-07 07:47:41.0  ...     19e2e  f8cc619f6f  1c90b51bb4
# 1283578     sms      0  2012-05-07 07:47:41.0  ...     19e2e  b42d04b0d7  9ef9616350
# 1283579     sms      0  2012-05-07 07:47:41.0  ...     19e2e  9f847444ba  c07a544c63
# 1283580     sms      0  2012-05-07 07:47:41.0  ...     19e2e  db13b7dfd7  8fccce7c15
# 1283581     sms      0  2012-05-07 07:47:41.0  ...     19e2e  cca0b90f3b  dedaa552e2
# 1283582     sms     50  2012-05-07 07:47:41.0  ...     19e2e  f54e480df9  928a59b635
# 1283583     sms      0  2012-05-07 07:47:41.0  ...     19e2e  7b724c1162  d0cd72cac5
# 1283584     sms      0  2012-05-07 07:47:41.0  ...       NaN         NaN         NaN
#
# [10 rows x 10 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1283585 entries, 0 to 1283584
# Data columns (total 10 columns):
# PRODUTC            1283585 non-null object
# VALUE              1283585 non-null int64
# DATETIME           1283585 non-null object
# CELL_ON_SITE       1283584 non-null object
# DW_A_NUMBER_INT    1283584 non-null object
# DW_B_NUMBER_INT    1283584 non-null object
# COUNTRY_A          1283584 non-null object
# COUNTRY_B          1283584 non-null object
# CELL_ID            1283584 non-null object
# SITE_ID            1186603 non-null object
# dtypes: int64(1), object(9)
# memory usage: 97.9+ MB

# %%
df2_new= df2.rename(columns={
   'PRODUTC' : 'PRODUCTS', 'VALUE' : 'VALUES',
   'DATETIME' : 'DATE_TIME',
   'CELL_ON_SITE':'CELL_ON_SITE', 'DW_A_NUMBER_INT' : 'DW_A_NUMBER_INT',
   'DW_B_NUMBER_INT' : 'DW_B_NUMBER_INT',
   'COUNTRY_A' : 'COUNTRY_A',
   'COUNTRY_B' : 'COUNTRY_B',
   'CELL_ID' : 'CELL_ID',
   'SIET_ID' : 'SITE_ID'
})
print(df2_new)
df2.head(10)
# Out:
#         PRODUCTS  VALUES  ...     CELL_ID     SITE_ID
# 0          Voice       0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms       0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms      25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice      56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice      14  ...  051KhYDCpv  051KhYDCpv
# 5           data       0  ...  /lrUXVGVcN  /lrUXVGVcN
# 6          Voice       0  ...  +38u2u/rfx  +38u2u/rfx
# 7          Voice       0  ...  09UjmmY1Ds  09UjmmY1Ds
# 8          Voice       0  ...  0DeimCpZOc  0DeimCpZOc
# 9            sms       0  ...  01MDiY5F89  01MDiY5F89
# 10           sms       0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 11           sms       0  ...  0MZBLLzPYZ  0MZBLLzPYZ
# 12           sms       0  ...  0//cZOoEXj  0//cZOoEXj
# 13           sms      25  ...  2dmu2Iy1CX  2dmu2Iy1CX
# 14         Voice       0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 15         Voice       0  ...  176sGHv7Ym  176sGHv7Ym
# ...

# %%
df3 = pd.read_csv('MoringaSchool_CB_CDR_20120509.csv')
df3.tail(10)
# Out:
#        PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 586881   Voice     29  2012-05-09 06:56:48.0  ...     19e2e  2a8c5b9124  1e751d08a4
# 586882   Voice     44  2012-05-09 06:56:48.0  ...     19e2e  9f1eeee836  1ddea341cd
# 586883   Voice     35  2012-05-09 06:56:48.0  ...     19e2e  93d38fc386  3ae1708153
# 586884   Voice      0  2012-05-09 06:56:48.0  ...     19e2e  42db650cd4  952ba02486
# 586885   Voice    120  2012-05-09 06:56:48.0  ...     19e2e  7f516fe61d  e04667f9c7
# 586886   Voice     14  2012-05-09 06:56:48.0  ...     19e2e  9e39dc6080  6edaac0f1e
# 586887   Voice      0  2012-05-09 06:56:48.0  ...     19e2e  79059318ae  1c7edd2f30
# 586888   Voice     25  2012-05-09 06:56:48.0  ...     19e2e  6c19e6ffea  ec36e9bdac
# 586889   Voice     72  2012-05-09 06:56:48.0  ...     19e2e  95cd70b9ed  694c55a591
# 586890   Voice     95  2012-05-09 06:56:48.0  ...       NaN         NaN         NaN
#
# [10 rows x 10 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715852 entries, 0 to 715851
# Data columns (total 10 columns):
# PRODUCT            715852 non-null object
# VALUE              715852 non-null int64
# DATE_TIME          715852 non-null object
# CELL_ON_SITE       715852 non-null object
# DW_A_NUMBER_INT    715851 non-null object
# DW_B_NUMBER_INT    715851 non-null object
# COUNTRY_A          715851 non-null object
# COUNTRY_B          715851 non-null object
# CELLID             715851 non-null object
# SIET_ID            636501 non-null object
# dtypes: int64(1), object(9)
# memory usage: 54.6+ MB

# %%
df3_new=df3.rename(columns={
   'PRODUTC' : 'PRODUCTS', 'VALUE' : 'VALUES',
   'DATETIME' : 'DATE_TIME',
   'CELL_ON_SITE':'CELL_ON_SITE', 'DW_A_NUMBER_INT' : 'DW_A_NUMBER_INT',
   'DW_B_NUMBER_INT' : 'DW_B_NUMBER_INT',
   'COUNTRY_A' : 'COUNTRY_A',
   'COUNTRY_B' : 'COUNTRY_B',
   'CELLID' : 'CELL_ID',
   'SIET_ID' : 'SITE_ID'
})
print(df3_new)
df3_new.head(10)
# Out:
#        PRODUCT  VALUES              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        Voice      61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1          sms       0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2        Voice      10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3          sms       0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4        Voice      22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# 5        Voice      10  2012-05-08 23:03:59.0  ...     19e2e  +e+xcimwre  +e+xcimwre
# 6          sms       0  2012-05-08 23:06:06.0  ...     19e2e  +R5ccmtyJf  +R5ccmtyJf
# 7        Voice      10  2012-05-08 23:06:55.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 8          sms      25  2012-05-08 23:07:09.0  ...     19e2e  13O1+JEun3  13O1+JEun3
# 9          sms       0  2012-05-08 23:07:38.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...

# %%
pd.isnull("MoringSchool_CB_CDR_20120507")
# Out:
# False

# %%
pd.isnull("MoringSchool_CB_CDR_20120508")
# Out:
# False

# %%
pd.isnull("MoringSchool_CB_CDR_20120509")
# Out:
# False

# %%
df3_new.drop(columns=['COUNTRY_A','COUNTRY_B'])
# Out:
#        PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0        Voice      61  ...  +38u2u/rfx  +38u2u/rfx
# 1          sms       0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2        Voice      10  ...  +ZaaZozy/+  +ZaaZozy/+
# 3          sms       0  ...  +cNeJzsTp3  +cNeJzsTp3
# 4        Voice      22  ...  /eeMklgyJA  /eeMklgyJA
# 5        Voice      10  ...  +e+xcimwre  +e+xcimwre
# 6          sms       0  ...  +R5ccmtyJf  +R5ccmtyJf
# 7        Voice      10  ...  +ZaaZozy/+  +ZaaZozy/+
# 8          sms      25  ...  13O1+JEun3  13O1+JEun3
# 9          sms       0  ...  /eeMklgyJA  /eeMklgyJA
# 10         sms       0  ...  /eeMklgyJA  /eeMklgyJA
# 11         sms       0  ...  /NPTR0H+5I  /NPTR0H+5I
# 12         sms       0  ...  18MlD9e2CO  18MlD9e2CO
# 13         sms       0  ...  0K+IDi1yjl  0K+IDi1yjl
# 14         sms       0  ...  2GgIN622rt  2GgIN622rt
# 15         sms      50  ...  051KhYDCpv  051KhYDCpv
# 16       Voice      14  ...  2aXXOLyR5M  2aXXOLyR5M
# ...

# %%
df2_new.drop(columns=['COUNTRY_A','COUNTRY_B'])
# Out:
#         PRODUCTS  VALUES  ...     CELL_ID     SITE_ID
# 0          Voice       0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms       0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms      25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice      56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice      14  ...  051KhYDCpv  051KhYDCpv
# 5           data       0  ...  /lrUXVGVcN  /lrUXVGVcN
# 6          Voice       0  ...  +38u2u/rfx  +38u2u/rfx
# 7          Voice       0  ...  09UjmmY1Ds  09UjmmY1Ds
# 8          Voice       0  ...  0DeimCpZOc  0DeimCpZOc
# 9            sms       0  ...  01MDiY5F89  01MDiY5F89
# 10           sms       0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 11           sms       0  ...  0MZBLLzPYZ  0MZBLLzPYZ
# 12           sms       0  ...  0//cZOoEXj  0//cZOoEXj
# 13           sms      25  ...  2dmu2Iy1CX  2dmu2Iy1CX
# 14         Voice       0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 15         Voice       0  ...  176sGHv7Ym  176sGHv7Ym
# ...

# %%
df1_new.drop(columns=['COUNTRY_A','COUNTRY_B'])
# Out:
#         PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0           sms       0  ...  +854AcBQT2  +854AcBQT2
# 1         Voice       0  ...  +854AcBQT2  +854AcBQT2
# 2           sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 3         Voice      37  ...  /xvRrCVKoQ  /xvRrCVKoQ
# 4           sms      25  ...  +bO+qkSonO  +bO+qkSonO
# 5           sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 6         Voice      41  ...  +laSrk7g6q  +laSrk7g6q
# 7         Voice      11  ...  +gySf02tKW  +gySf02tKW
# 8           sms       0  ...  /0FxP3az1x  /0FxP3az1x
# 9           sms       0  ...  0ecjmwPX21  0ecjmwPX21
# 10          sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 11          sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 12          sms       0  ...  +YzQI97cPp  +YzQI97cPp
# 13          sms       0  ...  +38u2u/rfx  +38u2u/rfx
# 14          sms       0  ...  0BRdojv2my  0BRdojv2my
# 15          sms       0  ...  +e+xcimwre  +e+xcimwre
# 16          sms       0  ...  +cNeJzsTp3  +cNeJzsTp3
# ...

# %%
pd.concat([df1_new,df2_new,df3_new],axis=1)
# Out:
#         PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0           sms       0  ...  +38u2u/rfx  +38u2u/rfx
# 1         Voice       0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2           sms       0  ...  +ZaaZozy/+  +ZaaZozy/+
# 3         Voice      37  ...  +cNeJzsTp3  +cNeJzsTp3
# 4           sms      25  ...  /eeMklgyJA  /eeMklgyJA
# 5           sms       0  ...  +e+xcimwre  +e+xcimwre
# 6         Voice      41  ...  +R5ccmtyJf  +R5ccmtyJf
# 7         Voice      11  ...  +ZaaZozy/+  +ZaaZozy/+
# 8           sms       0  ...  13O1+JEun3  13O1+JEun3
# 9           sms       0  ...  /eeMklgyJA  /eeMklgyJA
# 10          sms       0  ...  /eeMklgyJA  /eeMklgyJA
# 11          sms       0  ...  /NPTR0H+5I  /NPTR0H+5I
# 12          sms       0  ...  18MlD9e2CO  18MlD9e2CO
# 13          sms       0  ...  0K+IDi1yjl  0K+IDi1yjl
# 14          sms       0  ...  2GgIN622rt  2GgIN622rt
# 15          sms       0  ...  051KhYDCpv  051KhYDCpv
# 16          sms       0  ...  2aXXOLyR5M  2aXXOLyR5M
# ...

# %%
df1_new.dropna()
# Out:
#         PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0           sms       0  ...  +854AcBQT2  +854AcBQT2
# 1         Voice       0  ...  +854AcBQT2  +854AcBQT2
# 2           sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 3         Voice      37  ...  /xvRrCVKoQ  /xvRrCVKoQ
# 4           sms      25  ...  +bO+qkSonO  +bO+qkSonO
# 5           sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 6         Voice      41  ...  +laSrk7g6q  +laSrk7g6q
# 7         Voice      11  ...  +gySf02tKW  +gySf02tKW
# 8           sms       0  ...  /0FxP3az1x  /0FxP3az1x
# 9           sms       0  ...  0ecjmwPX21  0ecjmwPX21
# 10          sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 11          sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 12          sms       0  ...  +YzQI97cPp  +YzQI97cPp
# 13          sms       0  ...  +38u2u/rfx  +38u2u/rfx
# 14          sms       0  ...  0BRdojv2my  0BRdojv2my
# 15          sms       0  ...  +e+xcimwre  +e+xcimwre
# 16          sms       0  ...  +cNeJzsTp3  +cNeJzsTp3
# ...

# %%
df2_new.dropna()
# Out:
#         PRODUCTS  VALUES  ...     CELL_ID     SITE_ID
# 0          Voice       0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1            sms       0  ...  /+cKZKIp41  /+cKZKIp41
# 2            sms      25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3          Voice      56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4          Voice      14  ...  051KhYDCpv  051KhYDCpv
# 5           data       0  ...  /lrUXVGVcN  /lrUXVGVcN
# 6          Voice       0  ...  +38u2u/rfx  +38u2u/rfx
# 7          Voice       0  ...  09UjmmY1Ds  09UjmmY1Ds
# 8          Voice       0  ...  0DeimCpZOc  0DeimCpZOc
# 9            sms       0  ...  01MDiY5F89  01MDiY5F89
# 10           sms       0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 11           sms       0  ...  0MZBLLzPYZ  0MZBLLzPYZ
# 12           sms       0  ...  0//cZOoEXj  0//cZOoEXj
# 13           sms      25  ...  2dmu2Iy1CX  2dmu2Iy1CX
# 14         Voice       0  ...  0Fmr/IZtQ+  0Fmr/IZtQ+
# 15         Voice       0  ...  176sGHv7Ym  176sGHv7Ym
# ...

# %%
df3_new.dropna()
# Out:
#        PRODUCT  VALUES              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        Voice      61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1          sms       0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2        Voice      10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3          sms       0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4        Voice      22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# 5        Voice      10  2012-05-08 23:03:59.0  ...     19e2e  +e+xcimwre  +e+xcimwre
# 6          sms       0  2012-05-08 23:06:06.0  ...     19e2e  +R5ccmtyJf  +R5ccmtyJf
# 7        Voice      10  2012-05-08 23:06:55.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 8          sms      25  2012-05-08 23:07:09.0  ...     19e2e  13O1+JEun3  13O1+JEun3
# 9          sms       0  2012-05-08 23:07:38.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...

# %%
pd.concat([df1_new,df2_new,df3_new],axis=1)
# Out:
#         PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0           sms       0  ...  +38u2u/rfx  +38u2u/rfx
# 1         Voice       0  ...  +Fs4mTvdKx  +Fs4mTvdKx
# 2           sms       0  ...  +ZaaZozy/+  +ZaaZozy/+
# 3         Voice      37  ...  +cNeJzsTp3  +cNeJzsTp3
# 4           sms      25  ...  /eeMklgyJA  /eeMklgyJA
# 5           sms       0  ...  +e+xcimwre  +e+xcimwre
# 6         Voice      41  ...  +R5ccmtyJf  +R5ccmtyJf
# 7         Voice      11  ...  +ZaaZozy/+  +ZaaZozy/+
# 8           sms       0  ...  13O1+JEun3  13O1+JEun3
# 9           sms       0  ...  /eeMklgyJA  /eeMklgyJA
# 10          sms       0  ...  /eeMklgyJA  /eeMklgyJA
# 11          sms       0  ...  /NPTR0H+5I  /NPTR0H+5I
# 12          sms       0  ...  18MlD9e2CO  18MlD9e2CO
# 13          sms       0  ...  0K+IDi1yjl  0K+IDi1yjl
# 14          sms       0  ...  2GgIN622rt  2GgIN622rt
# 15          sms       0  ...  051KhYDCpv  051KhYDCpv
# 16          sms       0  ...  2aXXOLyR5M  2aXXOLyR5M
# ...

# %%
df1_new.drop(columns=['COUNTRY_A','COUNTRY_B'])
# Out:
#         PRODUCT  VALUES  ...     CELL_ID     SITE_ID
# 0           sms       0  ...  +854AcBQT2  +854AcBQT2
# 1         Voice       0  ...  +854AcBQT2  +854AcBQT2
# 2           sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 3         Voice      37  ...  /xvRrCVKoQ  /xvRrCVKoQ
# 4           sms      25  ...  +bO+qkSonO  +bO+qkSonO
# 5           sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 6         Voice      41  ...  +laSrk7g6q  +laSrk7g6q
# 7         Voice      11  ...  +gySf02tKW  +gySf02tKW
# 8           sms       0  ...  /0FxP3az1x  /0FxP3az1x
# 9           sms       0  ...  0ecjmwPX21  0ecjmwPX21
# 10          sms       0  ...  +laSrk7g6q  +laSrk7g6q
# 11          sms       0  ...  /MMplBlWjh  /MMplBlWjh
# 12          sms       0  ...  +YzQI97cPp  +YzQI97cPp
# 13          sms       0  ...  +38u2u/rfx  +38u2u/rfx
# 14          sms       0  ...  0BRdojv2my  0BRdojv2my
# 15          sms       0  ...  +e+xcimwre  +e+xcimwre
# 16          sms       0  ...  +cNeJzsTp3  +cNeJzsTp3
# ...
